# %%
#Curso Financial Data Analysis with Python https://www.youtube.com/watch?v=2ywUfs0rgtU&t=0s
import pandas as pd

# %%
data = pd.read_csv("AAPL.csv", index_col=0, parse_dates= True)
#con index_col = 0 le decimos a python que queremos que la primer columna sea nuestro indice y con parse_dates=true 
#le decimos que es un indece de fecha

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100039  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094820  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087861  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090035   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092646   73449600

# %%
data.loc['2022-01-01':]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  181.259918
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  178.959442
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  174.199158
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  171.291183
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  171.460495
# ...                ...         ...         ...         ...         ...
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.449997
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  146.100006
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.399994
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.429993
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  140.089996
#
#                Volume
# Date
# 2022-01-03  104487900
# 2022-01-04   99310400
# 2022-01-05   94537600
# ...

# %%
#Ponemos -1 para que nos muestre el ultimo valor existente

data.iloc[-1]
# Out:
# Open         1.425400e+02
# High         1.431000e+02
# Low          1.394500e+02
# Close        1.400900e+02
# Adj Close    1.400900e+02
# Volume       8.585910e+07
# Name: 2022-10-07 00:00:00, dtype: float64

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.449997
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  146.100006
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.399994
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.429993
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  140.089996
#
#                Volume
# Date
# 2022-10-03  114311700
# 2022-10-04   87830100
# 2022-10-05   79471000
# 2022-10-06   68402200
# 2022-10-07   85859100

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Close']
# Out:
# Date
# 1980-12-12      0.128348
# 1980-12-15      0.121652
# 1980-12-16      0.112723
# 1980-12-17      0.115513
# 1980-12-18      0.118862
#                  ...
# 2022-10-03    142.449997
# 2022-10-04    146.100006
# 2022-10-05    146.399994
# 2022-10-06    145.429993
# 2022-10-07    140.089996
# Name: Close, Length: 10545, dtype: float64

# %%
type(data['Close'])
# Out:
# pandas.core.series.Series

# %%
daily_change = data['Open'] - data['Close']

# %%
daily_change
# Out:
# Date
# 1980-12-12    0.000000
# 1980-12-15    0.000558
# 1980-12-16    0.000558
# 1980-12-17    0.000000
# 1980-12-18    0.000000
#                 ...
# 2022-10-03   -4.239990
# 2022-10-04   -1.070007
# 2022-10-05   -2.329987
# 2022-10-06    0.380005
# 2022-10-07    2.449997
# Length: 10545, dtype: float64

# %%
daily_pct_change = (data['Close'] - data['Open'])/data['Close']*100

# %%
daily_pct_change
# Out:
# Date
# 1980-12-12    0.000000
# 1980-12-15   -0.458685
# 1980-12-16   -0.495019
# 1980-12-17    0.000000
# 1980-12-18    0.000000
#                 ...
# 2022-10-03    2.976476
# 2022-10-04    0.732380
# 2022-10-05    1.591521
# 2022-10-06   -0.261298
# 2022-10-07   -1.748874
# Length: 10545, dtype: float64

# %%
norm = data['Close']/data['Close'].iloc[0]

# %%
norm
# Out:
# Date
# 1980-12-12       1.000000
# 1980-12-15       0.947829
# 1980-12-16       0.878261
# 1980-12-17       0.899998
# 1980-12-18       0.926092
#                  ...
# 2022-10-03    1109.873134
# 2022-10-04    1138.311512
# 2022-10-05    1140.648814
# 2022-10-06    1133.091229
# 2022-10-07    1091.485617
# Name: Close, Length: 10545, dtype: float64

# %%
data['Close'].iloc[0]*norm.iloc[-1]
# Out:
# 140.089996

# %%
#Ahora vamos a agregar la columna daily change a nuestro data frame. Una nueva columna...
data['Daily_change']= data['Open'] - data['Close']

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100039  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094820  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087861  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090035   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092646   73449600
#
#             Daily_change
# Date
# 1980-12-12      0.000000
# 1980-12-15      0.000558
# 1980-12-16      0.000558
# 1980-12-17      0.000000
# 1980-12-18      0.000000

# %%
data['Normalized']= data['Close']/data['Close'].iloc[0]

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100039  469033600
# 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094820  175884800
# 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087861  105728000
# 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090035   86441600
# 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092646   73449600
#
#             Daily_change  Normalized
# Date
# 1980-12-12      0.000000    1.000000
# 1980-12-15      0.000558    0.947829
# 1980-12-16      0.000558    0.878261
# 1980-12-17      0.000000    0.899998
# 1980-12-18      0.000000    0.926092

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-03  138.210007  143.070007  137.690002  142.449997  142.449997
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  146.100006
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  146.399994
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  145.429993
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  140.089996
#
#                Volume  Daily_change   Normalized
# Date
# 2022-10-03  114311700     -4.239990  1109.873134
# 2022-10-04   87830100     -1.070007  1138.311512
# 2022-10-05   79471000     -2.329987  1140.648814
# 2022-10-06   68402200      0.380005  1133.091229
# 2022-10-07   85859100      2.449997  1091.485617

# %%
#Vamos a buscar el minimo valor y el maximo valor con el min y el max, con el argmin y el argmax vamos a sacar el numero del indice y en base a eso podemos usar el iloc para ubicar la fecha

# %%
data['Close'].min()
# Out:
# 0.049107

# %%
data['Close'].argmin()
# Out:
# 395

# %%
data.iloc[395]
# Out:
# Open            4.966500e-02
# High            4.966500e-02
# Low             4.910700e-02
# Close           4.910700e-02
# Adj Close       3.827600e-02
# Volume          1.643264e+08
# Daily_change    5.580000e-04
# Normalized      3.826082e-01
# Name: 1982-07-08 00:00:00, dtype: float64

# %%
data['Close'].max()
# Out:
# 182.009995

# %%
data['Close'].argmax()
# Out:
# 10352

# %%
data.iloc[10352]
# Out:
# Open            1.778300e+02
# High            1.828800e+02
# Low             1.777100e+02
# Close           1.820100e+02
# Adj Close       1.812599e+02
# Volume          1.044879e+08
# Daily_change   -4.179993e+00
# Normalized      1.418098e+03
# Name: 2022-01-03 00:00:00, dtype: float64

# %%
#Vemos la diferencia entre el valor máximo de la serie y el último valor. 
(data['Close'].iloc[-1] / data['Close'].loc['2022-01-03'])*100 -100
# Out:
# -23.031701638143545

# %%
#Para sacar el promedio de toda la serie 
data['Close'].mean()
# Out:
# 15.781523283357041

# %%
#Para sacar el precio de cierre promedio de una determinada fecha, al argumento anterior le agregamos loc y la fecha desde la que empezamos a contar
data['Close'].loc['2022-01-01':].mean()
# Out:
# 158.4490674300518

# %%
#Graficos

import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
data.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot: xlabel='Date'>

# %%
data['Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
fig, ax = plt.subplots()
data['Close'].plot(ax=ax)
ax.set_ylabel('Price')
ax.set_title('AAPL')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL')

# %%
fig, ax = plt.subplots(2,2)
data['Open'].plot(ax=ax[0,0], title='AAPL Open')
data['Close'].plot(ax=ax[0,1], title='AAPL Close')
data['Volume'].plot(ax=ax[1,0], title='AAPL Volume')
data['Daily_change'].plot(ax=ax[1,1], title='AAPL Daily Change')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
data['Volume'].loc['2022-01-01':'2022-03-01'].plot.bar(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="654">
# <AxesSubplot: xlabel='Date'>

# %%
#Hasta aca vimos como sacar parametros y hacer graficos desde un archivo de csv que descargamos de yahoo finance o alguna otra pagina. 
#A partir de ahora vamos a ver como extraer esa información de una API para que, además, se actualice constantemente y de forma automatica. 
import pandas_datareader as pdr

# %%
import datetime as dt

# %%
ticker = "AAPL"
start = dt.datetime(2019, 1, 1)
data = pdr.get_data_yahoo(ticker, start)

# %%
data.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0  38.168346
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0  34.366497
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0  35.833580
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0  35.753826
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0  36.435398

# %%
#aca no hace falta configurar la columna de fecha dado que la API lo hace por nosotros 
data.index
# Out:
# DatetimeIndex(['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#                '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11',
#                '2019-01-14', '2019-01-15',
#                ...
#                '2022-10-10', '2022-10-11', '2022-10-12', '2022-10-13',
#                '2022-10-14', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='Date', length=960, freq=None)

# %%
data.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close
# Date
# 2022-10-17  142.410004
# 2022-10-18  143.750000
# 2022-10-19  143.860001
# 2022-10-20  143.389999
# 2022-10-21  147.270004

# %%
#Con pdr tambien podemos obtener un listado de todas las empresas del nasdaq
nasdaq_sym = pdr.get_nasdaq_symbols()

# %%
nasdaq_sym
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZY               True                       Zymergen Inc. - Common Stock
# ZYME             True                       Zymeworks Inc. Common Shares
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close
# Date
# 2022-10-17  142.410004
# 2022-10-18  143.750000
# 2022-10-19  143.860001
# 2022-10-20  143.389999
# 2022-10-21  147.270004

# %%
#Calcula el cambio porcentual respecto al precio anterior y agrega una nueva columna con esos valores
data['pct-change']= data['Close'].pct_change()

# %%
data.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0
#
#             Adj Close  pct-change
# Date
# 2019-01-02  38.168346         NaN
# 2019-01-03  34.366497   -0.099607
# 2019-01-04  35.833580    0.042689
# 2019-01-07  35.753826   -0.002226
# 2019-01-08  36.435398    0.019063

# %%
import numpy as np

# %%
data['Log_returns']= np.log(data['Close']/data['Close'].shift())

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close  pct-change  Log_returns
# Date
# 2022-10-17  142.410004    0.029123     0.028707
# 2022-10-18  143.750000    0.009409     0.009365
# 2022-10-19  143.860001    0.000765     0.000765
# 2022-10-20  143.389999   -0.003267    -0.003272
# 2022-10-21  147.270004    0.027059     0.026699

# %%
#calculamos la desviación standar diaria
data['Log_returns'].std()
# Out:
# 0.021555593866605494

# %%
volatility = data['Log_returns'].std()*252**0.5

# %%
volatility
# Out:
# 0.342184444400084

# %%
str_vol=str(round(volatility, 4)*100)

# %%
str_vol
# Out:
# '34.22'

# %%
fig, ax = plt.subplots()
data['Log_returns'].hist(ax=ax, bins=50, alpha=0.6, color='b')
ax.set_xlabel("Log returns")
ax.set_ylabel("Freq of log return")
ax.set_title("AAPL Volatility: " + str_vol + "%")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL Volatility: 34.22%')

# %%
#Calculamos el moving average de las ultimas 10 ruedas. 
#Si el promedio movil te da más bajo que el precio es que estamos en una onda alcistad
data['MA10'] = data['Close'].rolling(10).mean()

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close  pct-change  Log_returns        MA10
# Date
# 2022-10-17  142.410004    0.029123     0.028707  141.953999
# 2022-10-18  143.750000    0.009409     0.009365  141.718999
# 2022-10-19  143.860001    0.000765     0.000765  141.464999
# 2022-10-20  143.389999   -0.003267    -0.003272  141.261000
# 2022-10-21  147.270004    0.027059     0.026699  141.979001

# %%
data['EMA10']= data['Close'].ewm(span=10, adjust=False).mean()

# %%
data['MA100'] = data['Close'].rolling(100).mean()

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close  pct-change  Log_returns        MA10       EMA10  \
# Date
# 2022-10-17  142.410004    0.029123     0.028707  141.953999  141.992847
# 2022-10-18  143.750000    0.009409     0.009365  141.718999  142.312329
# 2022-10-19  143.860001    0.000765     0.000765  141.464999  142.593724
# 2022-10-20  143.389999   -0.003267    -0.003272  141.261000  142.738501
# 2022-10-21  147.270004    0.027059     0.026699  141.979001  143.562411
#
#                MA100
# Date
# 2022-10-17  151.2537
# 2022-10-18  151.2860
# ...

# %%
#Graficos los EMA y los MA junto con los precios de cierre. Si el EMA està por encima del MA, ooportunidad de compra
fix, ax = plt.subplots()
data[['MA10', 'EMA10','MA100']].loc['2022-01-01':].plot(ax=ax)
data['Close'].loc['2022-01-01':].plot(ax=ax, alpha=0.5)
ax.set_title('AAPl EMA, MA10 & MA100')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPl EMA, MA10 & MA100')

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close  pct-change  Log_returns        MA10       EMA10  \
# Date
# 2022-10-17  142.410004    0.029123     0.028707  141.953999  141.992847
# 2022-10-18  143.750000    0.009409     0.009365  141.718999  142.312329
# 2022-10-19  143.860001    0.000765     0.000765  141.464999  142.593724
# 2022-10-20  143.389999   -0.003267    -0.003272  141.261000  142.738501
# 2022-10-21  147.270004    0.027059     0.026699  141.979001  143.562411
#
#                MA100
# Date
# 2022-10-17  151.2537
# 2022-10-18  151.2860
# ...

# %%
#Vamos a calcular la MACD y la Signal Line. La MACD es la diferencia entre EMA12 (12 dias) y EMA26(26 dias). La Signal Line es la EMA9 (9días)
exp1=data['Close'].ewm(span=12, adjust=False).mean()
exp2=data['Close'].ewm(span=26, adjust=False).mean()
data['MACD']= exp1 - exp2
data['Signal_Line'] = data['MACD'].ewm(span=9, adjust=False).mean()

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close  pct-change  Log_returns        MA10       EMA10  \
# Date
# 2022-10-17  142.410004    0.029123     0.028707  141.953999  141.992847
# 2022-10-18  143.750000    0.009409     0.009365  141.718999  142.312329
# 2022-10-19  143.860001    0.000765     0.000765  141.464999  142.593724
# 2022-10-20  143.389999   -0.003267    -0.003272  141.261000  142.738501
# 2022-10-21  147.270004    0.027059     0.026699  141.979001  143.562411
#
#                MA100      MACD  Signal_Line
# Date
# ...

# %%
fix, ax = plt.subplots()
data[['MACD', 'Signal_Line']].loc['2022-01-01':].plot(ax=ax)
data['Close'].loc['2022-01-01':].plot(ax=ax, alpha=0.5, secondary_y=True) #Secondary_y es para setear un eje secundario para la data que estamos marcando. 
#Con el MACD y la Signal Line: Cuando la MACD está arriba de la Signal line, es señal de compra. Cuando la MACD está abajo de la Signal Line, es momento de vender.
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot: >

# %%
ticker = "QQQ"
start = dt.datetime(2019, 1, 1)
dataq = pdr.get_data_yahoo(ticker, start)

# %%
dataq.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-20  274.839996  267.920013  269.579987  269.109985  60605500.0
# 2022-10-21  275.970001  266.820007  267.980011  275.420013  77367900.0
# 2022-10-24  279.399994  271.970001  275.690002  278.450012  63963600.0
# 2022-10-25  284.600006  277.899994  279.410004  284.209991  59014500.0
# 2022-10-26  283.975006  277.430206  278.459991  277.929993  62504126.0
#
#              Adj Close
# Date
# 2022-10-20  269.109985
# 2022-10-21  275.420013
# 2022-10-24  278.450012
# 2022-10-25  284.209991
# 2022-10-26  277.929993

# %%
expA=dataq['Close'].ewm(span=12, adjust=False).mean()
expB=dataq['Close'].ewm(span=26, adjust=False).mean()
dataq['MACD']= expA - expB
dataq['Signal_Line'] = dataq['MACD'].ewm(span=9, adjust=False).mean()

# %%
fix, ax = plt.subplots()
dataq[['MACD', 'Signal_Line']].loc['2022-01-01':].plot(ax=ax)
dataq['Close'].loc['2022-01-01':].plot(ax=ax, alpha=0.5, secondary_y=True)
ax.set_title('QQQ')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'QQQ')

# %%
#Stochastic Oscillator
high14= data['High'].rolling(14).max()
low14= data['Low'].rolling(14).max()
data['%K']= (data['Close']- low14)*100/(high14-low14)
data['%D']= data['%K'].rolling(3).mean()

# %%
data.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-10-17  142.899994  140.270004  141.070007  142.410004  85250900.0
# 2022-10-18  146.699997  140.610001  145.490005  143.750000  99136600.0
# 2022-10-19  144.949997  141.500000  141.690002  143.860001  61758300.0
# 2022-10-20  145.889999  142.649994  143.020004  143.389999  64522000.0
# 2022-10-21  147.850006  142.649994  142.869995  147.270004  86464700.0
#
#              Adj Close  pct-change  Log_returns        MA10       EMA10  \
# Date
# 2022-10-17  142.410004    0.029123     0.028707  141.953999  141.992847
# 2022-10-18  143.750000    0.009409     0.009365  141.718999  142.312329
# 2022-10-19  143.860001    0.000765     0.000765  141.464999  142.593724
# 2022-10-20  143.389999   -0.003267    -0.003272  141.261000  142.738501
# 2022-10-21  147.270004    0.027059     0.026699  141.979001  143.562411
#
#                MA100      MACD  Signal_Line         %K          %D
# Date
# ...

# %%
fix, ax = plt.subplots()
data[['%K', '%D']].loc['2022-06-01':].plot(ax=ax)
ax.axhline(-800, c='r', alpha=0.3)
ax.axhline(-200, c='r', alpha=0.3)
#Cuando %K está debajo de %D, es señal de venta
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ticker = "META"
start = dt.datetime(2019, 1, 1)
datam = pdr.get_data_yahoo(ticker, start)

# %%
expA=datam['Close'].ewm(span=12, adjust=False).mean()
expB=datam['Close'].ewm(span=26, adjust=False).mean()
datam['MACD']= expA - expB
datam['Signal_Line'] = datam['MACD'].ewm(span=9, adjust=False).mean()

# %%
fix, ax = plt.subplots()
datam[['MACD', 'Signal_Line']].loc['2022-06-01':].plot(ax=ax)
datam['Close'].loc['2022-06-01':].plot(ax=ax, alpha=0.5, secondary_y=True)
ax.set_title('META')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'META')
